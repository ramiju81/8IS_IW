# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests
url = "https://api.coingecko.com/api/v3/simple/price"
params = {"ids":"bitcoin","vs_currencies":"usd"}
response = requests.get(url,params=params)
data = response.json()
print(data)
# Out:
# {'bitcoin': {'usd': 81576}}

# %%
response = requests.get(url, params = params)
print(response.status_code)
if response.status_code == 200:
  data = response.json()
  print(data)
else:
  print("Error:",response.status_code)
# Out:
# 429
# Error: 429

# %%
import requests
username = "juliram81"
url = f"https://api.github.com/users/{username}"
response = requests.get(url)
data = response.json()
print(data)
print(response.status_code)
if response.status_code == 200:
  print(f"""Usuarios: {data['login']}
         Repos públicos: {data['public_repos']}
         url: {data['html_url']}""")
else:
  print("Error:",response.status_code)
# Out:
# {'login': 'juliram81', 'id': 129083026, 'node_id': 'U_kgDOB7Gmkg', 'avatar_url': 'https://avatars.githubusercontent.com/u/129083026?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/juliram81', 'html_url': 'https://github.com/juliram81', 'followers_url': 'https://api.github.com/users/juliram81/followers', 'following_url': 'https://api.github.com/users/juliram81/following{/other_user}', 'gists_url': 'https://api.github.com/users/juliram81/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/juliram81/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/juliram81/subscriptions', 'organizations_url': 'https://api.github.com/users/juliram81/orgs', 'repos_url': 'https://api.github.com/users/juliram81/repos', 'events_url': 'https://api.github.com/users/juliram81/events{/privacy}', 'received_events_url': 'https://api.github.com/users/juliram81/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': None, 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'public_repos': 4, 'public_gists': 0, 'followers': 0, 'following': 0, 'created_at': '2023-03-27T14:36:57Z', 'updated_at': '2025-02-28T01:53:42Z'}
# 200
# Usuarios: juliram81
#          Repos públicos: 4
#          url: https://github.com/juliram81

# %%
import requests

text = "https://github.com/juliram81"
url = f"https://api.qrserver.com/v1/create-qr-code/?size=150x150&data={text}"

response = requests.get(url)
if response.status_code == 200:
  with open("qr_code2.png","wb") as f:
    f.write(response.content)
    print("QR code generado exitosamente")
else:
  print("Error:",response.status_code)
# Out:
# QR code generado exitosamente

# %%
import requests
dic_user = {"Usuario":"value1"}
var = input("Ingrese su usuario ")
dic_user["Usuario"] = var
username = dic_user["Usuario"]
print(var)
url = f"https://api.github.com/users/{var}"
response = requests.get(url)
data = response.json()
print(data)
print(response.status_code)
if response.status_code == 200:
  print(f"""Usuarios: {data['login']}
         Repos públicos: {data['public_repos']}
         url: {data['html_url']}""")
else:
  print("Error:",response.status_code)


text = data['html_url']
url = f"https://api.qrserver.com/v1/create-qr-code/?size=150x150&data={text}"

response = requests.get(url)
if response.status_code == 200:
  with open("qr_code5.png","wb") as f:
    f.write(response.content)
    print("QR code generado exitosamente")
else:
  print("Error:",response.status_code)
# Out:
# Ingrese su usuario MAB1144-python
# MAB1144-python
# {'login': 'MAB1144-Python', 'id': 75086331, 'node_id': 'MDQ6VXNlcjc1MDg2MzMx', 'avatar_url': 'https://avatars.githubusercontent.com/u/75086331?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MAB1144-Python', 'html_url': 'https://github.com/MAB1144-Python', 'followers_url': 'https://api.github.com/users/MAB1144-Python/followers', 'following_url': 'https://api.github.com/users/MAB1144-Python/following{/other_user}', 'gists_url': 'https://api.github.com/users/MAB1144-Python/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MAB1144-Python/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MAB1144-Python/subscriptions', 'organizations_url': 'https://api.github.com/users/MAB1144-Python/orgs', 'repos_url': 'https://api.github.com/users/MAB1144-Python/repos', 'events_url': 'https://api.github.com/users/MAB1144-Python/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MAB1144-Python/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': 'Brayan Andru Montenegro Embus', 'company': None, 'blog': 'www.linkedin.com/in/brayanandrumontenegroembus', 'location': 'Popayán Colombia ', 'email': None, 'hireable': None, 'bio': 'I am a physical engineer and research in data science, artificial intelligence y SLAM.', 'twitter_username': None, 'public_repos': 37, 'public_gists': 0, 'followers': 3, 'following': 1, 'created_at': '2020-11-26T15:42:54Z', 'updated_at': '2025-02-24T13:29:21Z'}
# 200
# Usuarios: MAB1144-Python
#          Repos públicos: 37
#          url: https://github.com/MAB1144-Python
# QR code generado exitosamente
